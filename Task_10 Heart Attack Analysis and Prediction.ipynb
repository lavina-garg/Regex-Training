# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
# %matplotlib inline

# %%
df = pd.read_csv('heart.csv') 
df1 = pd.read_csv('o2Saturation.csv')

# %%
df.head(10)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
# 5   57    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
# 7   44    1   1     120   263    0        1       173     0      0.0    2
# 8   52    1   2     172   199    1        1       162     0      0.5    2
# 9   57    1   2     150   168    0        1       174     0      1.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1
# ...

# %%
df1.head(10)
# Out:
#    98.6
# 0  98.6
# 1  98.6
# 2  98.6
# 3  98.1
# 4  97.5
# 5  97.5
# 6  97.5
# 7  97.5
# 8  97.5
# 9  97.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.shape
# Out:
# (303, 14)

# %%
df1.shape
# Out:
# (3585, 1)

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# 98.6    0
# dtype: int64

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trtbps       49
# chol        152
# fbs           2
# restecg       3
# thalachh     91
# exng          2
# oldpeak      40
# slp           3
# caa           5
# thall         4
# output        2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (302, 14)

# %%
figure = plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),data = df)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(x="age",data=df);

# %%
sns.countplot(x="sex",hue ='output' ,data=df);
plt.xticks(ticks=[0,1],labels=["female","male"])
plt.show()

# %%
tdata=df[df["output"]==1]
sns.histplot(tdata["thalachh"])
plt.xlabel("MAXIMUM HEART RATE REACHED WHEN OUTPUT 1")
plt.show()

# %%
tdata=df[df["output"]==0]
sns.histplot(tdata["thalachh"]);
plt.xlabel("MAXIMUM HEART RATE REACHED WHEN OUTPUT 0")
plt.show()

# %%
sns.violinplot(x = 'cp' , y = 'trtbps' , data = df)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='trtbps'>

# %%
sns.countplot(x = 'cp' , hue = 'output' , data = df)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
sns.barplot(df['fbs'],df['output'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fbs', ylabel='output'>

# %%
plt.figure(figsize = (9,5))
sns.histplot(data = df, x = "caa", hue = "output") 
plt.title("Distribution of no. of major blodd vessels w.r.t Heart Attack")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="age",y="thalachh",hue="output",data= df)
plt.title("EFFECT OF HEART ATTACK WITH INCREASE IN AGE AND MAXIMUM HEART RATE")
plt.show()

# %%
df.loc[df['age']<=20,'age']=0
df.loc[(df['age']>20 )& (df['age']<=40),'age'] =1
df.loc[(df['age']>40)&(df['age']<=60),'age'] =2
df.loc[df['age']>60,'age'] =3

# %%
sns.set_style('darkgrid')
figure = plt.figure(figsize=(18,8))
sns.barplot(x= 'age', y ='thall',data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='age', ylabel='thall'>

# %%
sns.pairplot(df[['age','trtbps','chol','thalachh','oldpeak','output']] , hue = 'output')
plt.show()

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0    3    1   3     145   233    1        0       150     0      2.3    0
# 1    1    1   2     130   250    0        1       187     0      3.5    0
# 2    2    0   1     130   204    0        0       172     0      1.4    2
# 3    2    1   1     120   236    0        1       178     0      0.8    2
# 4    2    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
drop_cols = ['chol','trtbps','oldpeak','thalachh']
df = df.drop(drop_cols, axis = 1)

# %%
df.head()
# Out:
#    age  sex  cp  fbs  restecg  exng  slp  caa  thall  output
# 0    3    1   3    1        0     0    0    0      1       1
# 1    1    1   2    0        1     0    0    0      2       1
# 2    2    0   1    0        0     0    2    0      2       1
# 3    2    1   1    0        1     0    2    0      2       1
# 4    2    0   0    0        1     1    2    0      2       1

# %% [markdown]
# ## Linear Regression

# %%
X_train = df.drop(['output'] , axis =1).values
Y_train = df['output'].values

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X_train , Y_train, test_size = 0.20)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test , y_test)
# Out:
# 0.5057358725978036

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 0.69299316,  0.83426838,  0.86744846,  0.02592314,  0.79232518,
#         0.1257612 ,  0.26045773,  0.19113694,  0.73645352,  0.30664444,
#         1.14375802,  0.14039745,  0.66749509, -0.01782961,  0.4474135 ,
#         0.6845027 ,  0.75441756,  0.52431408,  0.5082771 ,  0.62278591,
#         0.38379092,  0.65888398, -0.01625886,  0.11408243,  0.64309286,
#         0.79817031,  0.74396554, -0.13177762,  0.37842982,  0.79788991,
#        -0.34004271,  0.02644944,  1.12412709, -0.01782961, -0.24572563,
#         0.67688027,  0.32512051,  1.02842352,  0.25521992,  0.77255159,
#         0.5088379 ,  0.91183792,  1.01045948,  0.85012113,  0.72980169,
#        -0.01782961,  0.69356096,  0.6845027 ,  0.96590003,  0.96701938,
#         0.49130399,  0.67865757,  0.79817031,  0.04388718,  0.08678674,
#         0.38042363,  0.57055469,  0.42863077,  0.79817031,  0.89387388,
#         0.44578811])

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.8688524590163934
